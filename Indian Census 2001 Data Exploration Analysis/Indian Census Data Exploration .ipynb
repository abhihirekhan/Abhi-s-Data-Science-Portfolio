# %% [markdown]
# India census data exploration as per states. There are many states and each state consists of many cities. These cities has population which can be explore on the basis of many other attributes

# %%
 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
 

 
 
file =r"C:\Users\user\Desktop\portfolio -E\Indian Census 2001 Data Exploration Analysis\all (1).csv"
df=pd.read_csv(file,sep=",")

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
plt.figure(figsize=(10,5))
count =df['State'].value_counts()
count.plot("bar")
plt.xlabel("State name",size=20)
plt.ylabel("No. of cities", size=20)
plt.title("Cities per state", size= 20)
plt.savefig("census1.jpg")

# %%
print(count.values)
person=df['Persons']
cols = ['Persons','Below.Primary', 'Primary', 'Middle', 'Matric.Higher.Secondary.Diploma',
                'Graduate.and.Above']
temp = df[cols + ['State']].groupby('State').sum()

density =temp.iloc[:,1].values/count.values
# Out:
# [70 45 37 35 32 30 29 27 25 23 22 19 18 18 17 16 14 14 13 13 12  9  8  8
#   8  7  4  4  4  2  2  2  1  1  1]

# %%
#plt.figure(figsize=(10,8))

#plt.ylabel("Density", size=20)
#plt.title("Totals Persons per city in a State", size= 20)

#plt.bar(count.values, density,color="red")
#plt.xticks(count.values, count.index)
#plt.savefig("census2.jpg")
print(count+density)
# Out:
# UP                  8.328714e+02
# MP                  2.013446e+05
# Bihar               4.056919e+03
# Maharashtra         1.173718e+05
# Rajasthan           2.466048e+05
# TN                  1.265991e+05
# Orrisa              3.081345e+03
# Karnataka           8.257037e+02
# Gujarat             1.069320e+03
# Assam               6.675835e+04
# Andhra              8.608636e+03
# Haryana             4.255065e+05
# WB                  4.540006e+04
# Jharkhand           1.493087e+05
# Punjab              5.063347e+04
# CG                  1.967536e+05
# Kerala              4.935670e+05
# JK                  3.522344e+05
# ArunachalPradesh    9.636154e+02
# Uttranchal          7.845715e+05
# HP                  1.339337e+06
# Delhi               2.140589e+04
# Manipur             5.835250e+04
# Mizoram             2.991062e+04
# Nagaland            2.871450e+04
# Meghalya            7.927993e+05
# Pondicherry         2.416175e+04
# Tripura             6.763878e+05
# Sikkim              2.248570e+06
# Goa                 5.456250e+04
# AN                  3.246346e+06
# D_D                 3.240445e+05
# Lakshdweep          1.922694e+07
# Chandigarh          1.156891e+06
# D_N_H               1.634770e+07
# Name: State, dtype: float64

# %%
# Scattered plot of count per city
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

file =r"C:\Users\user\Desktop\portfolio -E\Indian Census 2001 Data Exploration Analysis\all (1).csv"
df=pd.read_csv(file,sep=",")

plt.figure(figsize=(10,5))
count =df['State'].value_counts()
plt.xlabel("State name",size=20)
plt.ylabel("No. of cities", size=20)
plt.title("Cities per state", size= 20)
plt.savefig("census1.jpg")
plt.scatter(range(len(count)), count)
plt.show()
