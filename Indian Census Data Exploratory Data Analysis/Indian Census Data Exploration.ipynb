# %% [markdown]
# India census data exploration as per states. There are many states and each state consists of many cities. These cities has population which can be explore on the basis of many other attributes

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
 
 
file =r"C:\Users\user\Desktop\portfolio -E\Indian Census Data Exploratory Data Analysis\all (1).csv"
df=pd.read_csv(file,sep=",")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'District', 'Persons', 'Males', 'Females',
#        'Growth..1991...2001.', 'Rural', 'Urban', 'Scheduled.Caste.population',
#        'Percentage...SC.to.total', 'Number.of.households',
#        'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#        'Sex.ratio..0.6.years.', 'Scheduled.Tribe.population',
#        'Percentage.to.total.population..ST.', 'Persons..literate',
#        'Males..Literate', 'Females..Literate', 'Persons..literacy.rate',
#        'Males..Literatacy.Rate', 'Females..Literacy.Rate', 'Total.Educated',
#        'Data.without.level', 'Below.Primary', 'Primary', 'Middle',
#        'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above', 'X0...4.years',
#        'X5...14.years', 'X15...59.years', 'X60.years.and.above..Incl..A.N.S..',
#        'Total.workers', 'Main.workers', 'Marginal.workers', 'Non.workers',
#        'SC.1.Name', 'SC.1.Population', 'SC.2.Name', 'SC.2.Population',
#        'SC.3.Name', 'SC.3.Population', 'Religeon.1.Name',
#        'Religeon.1.Population', 'Religeon.2.Name', 'Religeon.2.Population',
#        'Religeon.3.Name', 'Religeon.3.Population', 'ST.1.Name',
#        'ST.1.Population', 'ST.2.Name', 'ST.2.Population', 'ST.3.Name',
#        'ST.3.Population', 'Imp.Town.1.Name', 'Imp.Town.1.Population',
#        'Imp.Town.2.Name', 'Imp.Town.2.Population', 'Imp.Town.3.Name',
#        'Imp.Town.3.Population', 'Total.Inhabited.Villages',
#        'Drinking.water.facilities', 'Safe.Drinking.water',
#        'Electricity..Power.Supply.', 'Electricity..domestic.',
#        'Electricity..Agriculture.', 'Primary.school', 'Middle.schools',
#        'Secondary.Sr.Secondary.schools', 'College', 'Medical.facility',
#        'Primary.Health.Centre', 'Primary.Health.Sub.Centre',
#        'Post..telegraph.and.telephone.facility', 'Bus.services',
#        'Paved.approach.road', 'Mud.approach.road', 'Permanent.House',
#        'Semi.permanent.House', 'Temporary.House'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0   State                                           District  \
# 0           1      AN  District Andamans (01), Andaman & Nicobar Isla...
# 1           2      AN  District Nicobars (02), Andaman & Nicobar Isla...
# 2           3  Andhra        District Adilabad (01), Andhra Pradesh (28)
# 3           4  Andhra       District Nizamabad (02), Andhra Pradesh (28)
# 4           5  Andhra      District Karimnagar (03), Andhra Pradesh (28)
#
#    Persons    Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   314084   170319   143765                30.14   197886  116198
# 1    42068    22653    19415                 7.19    42068       -
# 2  2488003  1250958  1237045                19.06  1827986     NaN
# 3  2345685  1162905  1182780                14.98  1920947     NaN
# 4  3491822  1747968  1743854                14.47  2813010     NaN
#
#   Scheduled.Caste.population  ... Medical.facility  Primary.Health.Centre  \
# 0                          -  ...              102                     16
# 1                          -  ...               38                      4
# 2                        NaN  ...              976                     61
# 3                        NaN  ...              614                     50
# 4                        NaN  ...              863                     70
#
#    Primary.Health.Sub.Centre  Post..telegraph.and.telephone.facility  \
# 0                         78                                   161.0
# 1                         31                                    36.0
# 2                        432                                   558.0
# 3                        330                                   602.0
# 4                        475                                   795.0
#
#    Bus.services Paved.approach.road Mud.approach.road  Permanent.House  \
# 0           187                 201               243             28.7
# 1            49                  51               111             28.0
# 2           814                 979               544             53.0
# 3           746                 760                82             52.8
# 4           912                 823               218             55.8
#
#    Semi.permanent.House  Temporary.House
# 0                  39.1             32.0
# 1                  33.3             38.7
# 2                  39.9              7.0
# 3                  37.6              9.6
# 4                  36.4              7.8
#
# [5 rows x 82 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0       Persons         Males       Females  \
# count  590.000000  5.900000e+02  5.900000e+02  5.900000e+02
# mean   295.500000  1.732902e+06  8.966605e+05  8.362419e+05
# std    170.462606  1.329998e+06  6.934142e+05  6.381679e+05
# min      1.000000  3.139400e+04  1.589300e+04  1.478300e+04
# 25%    148.250000  8.127185e+05  4.207508e+05  3.890438e+05
# 50%    295.500000  1.487712e+06  7.706160e+05  7.133320e+05
# 75%    442.750000  2.395986e+06  1.248934e+06  1.142946e+06
# max    590.000000  9.610788e+06  4.916370e+06  4.694418e+06
#
#        Number.of.households  Household.size..per.household.  \
# count          5.870000e+02                      587.000000
# mean           3.258233e+05                        5.436116
# std            2.666372e+05                        0.846952
# min            6.054000e+03                        4.000000
# 25%            1.559300e+05                        5.000000
# 50%            2.686090e+05                        5.000000
# 75%            4.337020e+05                        6.000000
# max            1.838426e+06                        8.000000
#
#        Sex.ratio..females.per.1000.males.  Sex.ratio..0.6.years.  \
# count                          587.000000             587.000000
# mean                           934.800681             929.388416
# std                             62.718746              47.554772
# min                            591.000000             766.000000
# 25%                            895.000000             912.000000
# 50%                            938.000000             942.000000
# 75%                            974.500000             962.000000
# max                           1147.000000            1035.000000
#
#        Persons..literate  Males..Literate  ...  Imp.Town.3.Population  \
# count       5.900000e+02     5.900000e+02  ...             482.000000
# mean        9.442850e+05     5.670726e+05  ...           41223.562241
# std         8.437970e+05     4.845297e+05  ...           52626.613978
# min         1.342400e+04     8.733000e+03  ...             605.000000
# 25%         4.144205e+05     2.541402e+05  ...           17390.250000
# 50%         7.693050e+05     4.681805e+05  ...           29149.000000
# 75%         1.220172e+06     7.617885e+05  ...           47965.000000
# max         6.617264e+06     3.853376e+06  ...          704002.000000
#
#        Total.Inhabited.Villages  Drinking.water.facilities  \
# count                578.000000                 578.000000
# mean                1016.451557                1009.671280
# std                  816.524396                 809.966443
# min                    2.000000                   2.000000
# 25%                  467.750000                 466.250000
# 50%                  891.000000                 886.500000
# 75%                 1386.000000                1376.500000
# max                10548.000000               10475.000000
#
#        Safe.Drinking.water  Electricity..Power.Supply.  Primary.school  \
# count           578.000000                  578.000000      578.000000
# mean            992.044983                  774.759516      796.794118
# std             801.088455                  611.197664      555.064067
# min               1.000000                    2.000000        1.000000
# 25%             442.750000                  311.500000      397.500000
# 50%             881.500000                  645.500000      758.500000
# 75%            1368.750000                 1086.750000     1133.750000
# max           10455.000000                 4835.000000     6133.000000
#
#        Post..telegraph.and.telephone.facility  Permanent.House  \
# count                              578.000000       590.000000
# mean                               419.726644        47.624644
# std                                331.545869        24.603409
# min                                  2.000000         1.600000
# 25%                                172.500000        28.225000
# 50%                                354.500000        47.550000
# 75%                                580.750000        66.300000
# max                               2346.000000        98.600000
#
#        Semi.permanent.House  Temporary.House
# count            590.000000       590.000000
# mean              32.856000        19.490051
# std               21.587237        20.760061
# min                1.000000         0.100000
# 25%               14.600000         3.400000
# 50%               28.850000        10.750000
# 75%               47.175000        30.175000
# max               95.000000        85.600000
#
# [8 rows x 47 columns]

# %%
plt.figure(figsize=(12,8))
count =df['State'].value_counts()
count.plot("bar")
plt.xlabel("State name",size=20,color='g')
plt.ylabel("No. of cities", size=20,color='orange')
plt.title("Cities per state", size= 20)
plt.savefig("census1.jpg")

# %%
person=df['Persons']
temp = df.groupby('State').sum()
print(temp.columns)
temp
# Out:
# Index(['Unnamed: 0', 'Persons', 'Males', 'Females', 'Number.of.households',
#        'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#        'Sex.ratio..0.6.years.', 'Persons..literate', 'Males..Literate',
#        'Females..Literate', 'Persons..literacy.rate', 'Males..Literatacy.Rate',
#        'Females..Literacy.Rate', 'Total.Educated', 'Data.without.level',
#        'Below.Primary', 'Primary', 'Middle', 'Matric.Higher.Secondary.Diploma',
#        'Graduate.and.Above', 'X0...4.years', 'X5...14.years', 'X15...59.years',
#        'X60.years.and.above..Incl..A.N.S..', 'Total.workers', 'Main.workers',
#        'Marginal.workers', 'Non.workers', 'SC.1.Population', 'SC.2.Population',
#        'SC.3.Population', 'Religeon.1.Population', 'Religeon.2.Population',
#        'Religeon.3.Population', 'Imp.Town.1.Population',
#        'Imp.Town.2.Population', 'Imp.Town.3.Population',
#        'Total.Inhabited.Villages', 'Drinking.water.facilities',
#        'Safe.Drinking.water', 'Electricity..Power.Supply.', 'Primary.school',
#        'Post..telegraph.and.telephone.facility', 'Permanent.House',
#        'Semi.permanent.House', 'Temporary.House'],
#       dtype='object')
#                   Unnamed: 0    Persons     Males   Females  \
# State
# AN                         3     356152    192972    163180
# Andhra                   297   71308587  36067773  35240814
# ArunachalPradesh         403    1097968    579941    518027
# Assam                   1127   26655528  13777037  12878491
# Bihar                   2923   82998509  43243795  39754714
# CG                      1688   20833803  10474218  10359585
# Chandigarh               114     900635    506938    393697
# D_D                      231     158204     92512     65692
# D_N_H                    126     220490    121666     98824
# Delhi                   1089   13850507   7607234   6243273
# Goa                      255    1347668    687248    660420
# Gujarat                 3525   50671017  26385577  24285440
# HP                      2142    6077900   3087940   2989960
# Haryana                 3097   21144564  11363953   9780611
# JK                      2933   10143700   5360926   4782774
# Jharkhand               3483   26945829  13885037  13060792
# Meghalya                                      6762.0                 6811.0
# Mizoram                                       7442.0                 7690.0
# Nagaland                                      7255.0                 7707.0
# Orrisa                                       28362.0                27679.0
# Pondicherry                                   4134.0                 3818.0
# Punjab                                       14974.0                13552.0
# Rajasthan                                    29460.0                29080.0
# Sikkim                                        3452.0                 3878.0
# TN                                           29868.0                28291.0
# Tripura                                       3782.0                 3860.0
# UP                                           62659.0                64037.0
# Uttranchal                                   13090.0                11961.0
# WB                                           16841.0                17268.0
#
#                   Persons..literate  Males..Literate  ...  \
# State                                                 ...
# AN                           253135           146831  ...
# Andhra                     37126595         21940112  ...
# ArunachalPradesh             484785           303281  ...
# Assam                      14015354          8188697  ...
# Bihar                      31109577         20644376  ...
# CG                         11173149          6711395  ...
# Chandigarh                   643245           382686  ...
# D_D                          107600            70992  ...
# D_N_H                        103904            72149  ...
# Delhi                       9664764          5700847  ...
# Goa                          985562           541032  ...
# Gujarat                    29827750         17833273  ...
# HP                          4041621          2278386  ...
# Haryana                    12093677          7480209  ...
# JK                          4807286          3060628  ...
# Jharkhand                  11777201          7646857  ...
# Karnataka                  30434962         17661211  ...
# Kerala                     25485688         12753602  ...
# Lakshdweep                    44683            24511  ...
# MP                         31592563         19672274  ...
# Maharashtra                63965943         37184963  ...
# Manipur                     1230027           706544  ...
# Meghalya                    1157875           614272  ...
# Mizoram                      661445           350105  ...
# Nagaland                    1132323           640201  ...
# Orrisa                     19165622         11583073  ...
# Pondicherry                  696367           378758  ...
# Punjab                     14756970          8442293  ...
# Rajasthan                  27702010         18047157  ...
# Sikkim                       318335           189060  ...
# TN                         40524545         22809662  ...
# Tripura                     2022099          1150707  ...
# UP                         75719284         48901413  ...
# Uttranchal                  5105782          3008875  ...
# WB                         47196401         27452426  ...
#
#                   Imp.Town.3.Population  Total.Inhabited.Villages  \
# State
# AN                               6787.0                     501.0
# Andhra                        1776596.0                   25290.0
# ArunachalPradesh                    0.0                    3863.0
# Assam                          275723.0                   25124.0
# Bihar                          650793.0                   39032.0
# CG                             261183.0                   19744.0
# Chandigarh                      16218.0                      23.0
# D_D                                 0.0                      23.0
# D_N_H                               0.0                      70.0
# Delhi                         1755173.0                     158.0
# Goa                             39120.0                     347.0
# Gujarat                       1065551.0                   18066.0
# HP                              55832.0                   17495.0
# Haryana                        482655.0                    6764.0
# JK                             133737.0                    6417.0
# Jharkhand                      436457.0                   29354.0
# Karnataka                     1245788.0                   24823.0
# Kerala                         590619.0                    1364.0
# Lakshdweep                       7353.0                       8.0
# MP                            1035614.0                   52117.0
# Maharashtra                   2087425.0                   41095.0
# Manipur                         37802.0                    1708.0
# Meghalya                        34292.0                    5782.0
# Mizoram                         23288.0                     707.0
# Nagaland                            0.0                    1278.0
# Orrisa                         447745.0                   45868.0
# Pondicherry                      7412.0                      92.0
# Punjab                         645113.0                   12278.0
# Rajasthan                      965238.0                   39752.0
# Sikkim                           5432.0                     450.0
# TN                            1589459.0                   15400.0
# Tripura                         62447.0                     858.0
# Delhi                                              147.0           813.10
# Goa                                                183.0           140.60
# Gujarat                                          13073.0          1504.20
# HP                                               12034.0           749.60
# Haryana                                           4927.0          1249.40
# JK                                                2333.0           619.74
# Jharkhand                                         3210.0           494.60
# Karnataka                                        15793.0          1318.80
# Kerala                                            1363.0           951.50
# Lakshdweep                                           8.0            95.30
# MP                                               18619.0          1900.30
# Maharashtra                                      20957.0          1697.80
# Manipur                                            383.0            51.90
# Meghalya                                           491.0           120.30
# Mizoram                                            312.0           348.90
# Nagaland                                           375.0           121.30
# Orrisa                                           14711.0           732.80
# Pondicherry                                         92.0           278.80
# Punjab                                           10587.0          1460.60
# Rajasthan                                        19480.0          1982.50
# Sikkim                                             286.0           129.50
# TN                                               13897.0          1684.40
# Tripura                                            612.0            32.20
# UP                                               34000.0          3713.20
# Uttranchal                                        4734.0          1166.60
# WB                                               12771.0           658.40
#
#                   Semi.permanent.House  Temporary.House
# State
# AN                               72.40            70.70
# Andhra                          502.60           507.30
# ArunachalPradesh                248.00           781.00
# Assam                           694.10          1184.90
# Bihar                          1039.50          1192.30
# CG                             1195.60            50.80
# Chandigarh                        7.00             3.20
# D_D                               9.40             1.90
# D_N_H                            51.60             2.60
# Delhi                            44.70            42.00
# Goa                              55.50             3.90
# Gujarat                         858.30           136.60
# HP                              380.60            69.40
# Haryana                         535.90           114.30
# JK                              545.44           232.33
# Jharkhand                      1093.20           212.20
# Karnataka                      1080.80           299.10
# Kerala                          308.80           138.70
# Lakshdweep                        2.90             1.80
# MP                             2472.30           127.20
# Maharashtra                    1523.80           276.20
# Manipur                         412.50           335.50
# Meghalya                        247.70           331.40
# Mizoram                         226.10           224.70
# Nagaland                        426.80           251.50
# Orrisa                          776.10          1390.90
# Pondicherry                      42.00            79.10
# Punjab                          152.60            87.10
# Rajasthan                       742.20           474.00
# Sikkim                          196.80            73.50
# TN                              565.30           749.30
# Tripura                         155.30           212.30
# UP                             1925.00          1361.40
# Uttranchal                       70.30            63.10
# WB                              723.90           416.90
#
# [35 rows x 47 columns]

# %%
count= count.reindex(sorted(count.index))
#print(count)
density =temp['Persons']/count.values/10**5
#temp['Persons']

# %%
plt.figure(figsize=(12,12))
plt.title("Totals Persons per city in a State (City density)", size= 20)

plt.pie(density.values,labels=density.index, shadow=True)
plt.savefig("census2.jpg")

# %% [markdown]
# **Above result shows Andhra pradesh and West Bengal has more city density compare to other states.**

# %% [markdown]
# Now we will see state wise details of each feature.
# -----------

# %%
#	Household.size..per.household.	Sex.ratio..females.per.1000.males.	Sex.ratio..0.6.years.	Persons..literate	Males..Literate	...	Imp.Town.3.Population	Total.Inhabited.Villages	Drinking.water.facilities	Safe.Drinking.water	Electricity..Power.Supply.	Primary.school	Post..telegraph.and.telephone.facility	Permanent.House	Semi.permanent.House	Temporary.House
plt.figure(figsize=(14,12))
plt.title("Number of households state wise", size= 20)

plt.pie(temp['Number.of.households'].values/100,labels=density.index, shadow=True)
plt.savefig("census2.jpg")

# %%
plt.figure(figsize=(12,12))
plt.title("Sex.ratio..females.per.1000.males", size= 20)

plt.pie(temp['Sex.ratio..females.per.1000.males.'].values/100,labels=density.index, shadow=True)
plt.show()

# %%
#	Household.size..per.household.	.	Sex.ratio..0.6.years.		Males..Literate	...	Imp.Town.3.Population	Total.Inhabited.Villages	Drinking.water.facilities	Safe.Drinking.water	Electricity..Power.Supply.	Primary.school	Post..telegraph.and.telephone.facility	Permanent.House	Semi.permanent.House	Temporary.House
plt.figure(figsize=(12,12))
plt.title("Persons..literate Per person", size= 20)

plt.pie(temp['Persons..literate'].values/temp['Persons'],labels=density.index,autopct='%1.1f%%', shadow=True)
plt.show()

# %%
#	Household.size..per.household.	.	Sex.ratio..0.6.years.		Males..Literate	...	Imp.Town.3.Population	Total.Inhabited.Villages	Drinking.water.facilities	Safe.Drinking.water	Electricity..Power.Supply.	Primary.school	Post..telegraph.and.telephone.facility	Permanent.House	Semi.permanent.House	Temporary.House
plt.figure(figsize=(12,12))
plt.title("Drinking.water.facilities per Person", size= 20, color= 'm')

plt.pie(temp['Drinking.water.facilities'].values/temp['Persons']*10**4,labels=density.index, shadow=True)
plt.show()

# %% [markdown]
# **Above graph shows Meghalaya,HP and Arunchal has better water facilities.**

# %%
#	Household.size..per.household.	.	Sex.ratio..0.6.years.		Males..Literate	...	Imp.Town.3.Population	Total.Inhabited.Villages	Drinking.water.facilities	Safe.Drinking.water	Electricity..Power.Supply.	Primary.school	Post..telegraph.and.telephone.facility	Permanent.House	Semi.permanent.House	Temporary.House
plt.figure(figsize=(12,12))
plt.title("Safe.Drinking.water per Person", size= 20)

plt.pie(temp['Safe.Drinking.water'].values/temp['Persons']*10**4,labels=density.index, shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.title("Total.Inhabited.Villages", size= 20, color= 'm')
plt.pie(temp['Total.Inhabited.Villages'].values/100,labels=density.index, shadow=True)
plt.show()

# %%
l =np.array(temp[['Permanent.House','Semi.permanent.House','Temporary.House']])
l.shape
# Out:
# (35, 3)

# %%
#	Household.size..per.household.	.	Sex.ratio..0.6.years.		Males..Literate	...	Imp.Town.3.Population	Total.Inhabited.Villages	Electricity..Power.Supply.	Primary.school	Post..telegraph.and.telephone.facility	Permanent.House	Semi.permanent.House	Temporary.House
df2 = pd.DataFrame(l, columns= ['Permanent.House','Semi.permanent.House','Temporary.House'], index=temp.index)
df2.plot.bar(figsize=(12,8),stacked=True)

# %% [markdown]
# **MP is showing better result comparatively.**

# %%
df2 = pd.DataFrame(np.array(temp[['Males','Females']]), columns= ['Males','Females'], index=temp.index)
df2.plot.bar(figsize=(12,8),color = ['navy','red'])

# %% [markdown]
# **Difference is multiple of 10 power 8.**

# %%
df2 = pd.DataFrame(np.array(temp[['Below.Primary', 'Primary', 'Middle',
       'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above',]]), columns= ['Below.Primary', 'Primary', 'Middle',
       'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above'], index=temp.index)
df2.plot.bar(figsize=(12,8),stacked = True)

# %%
df2 = pd.DataFrame(np.array(temp[['X5...14.years', 'X15...59.years', 
                                  'X60.years.and.above..Incl..A.N.S..']]),columns=['X5...14.years', 'X15...59.years', 
                                  'X60.years.and.above..Incl..A.N.S..'], index=temp.index)
df2.plot.barh(figsize=(12,8),stacked = True,title="State wise age groups")

# %%
df2 = pd.DataFrame(np.array(temp[['Males..Literate', 'Females..Literate']]),
                   columns=['Males..Literate', 'Females..Literate'], index=temp.index)
df2.plot.bar(figsize=(12,8),stacked = True)

# %%
df2 = pd.DataFrame(temp['Post..telegraph.and.telephone.facility']/temp['Persons']*1000,
                   columns=['Post telegraph and telephone facility per Person'], index=temp.index)
df2.plot.bar(figsize=(12,8),stacked = True)

# %% [markdown]
# **Above graph shows facility per person. HP is providing better facility.**

# %%
df2 = pd.DataFrame(np.array(temp[['Main.workers', 'Marginal.workers', 'Non.workers']]),
                   columns=['Main.workers', 'Marginal.workers', 'Non.workers'], index=temp.index)
df2.plot.bar(figsize=(12,8),stacked = True)

# %%
l =df[['State','SC.1.Name', 'SC.1.Population', 'SC.2.Name', 'SC.2.Population',
       'SC.3.Name', 'SC.3.Population', 'Religeon.1.Name',
       'Religeon.1.Population', 'Religeon.2.Name', 'Religeon.2.Population',
       'Religeon.3.Name', 'Religeon.3.Population', 'ST.1.Name',
       'ST.1.Population', 'ST.2.Name', 'ST.2.Population', 'ST.3.Name',
       'ST.3.Population']]

l.head(20)
# Out:
#      State                         SC.1.Name  SC.1.Population SC.2.Name  \
# 0       AN  No Scheduled Castes in this area              NaN       NaN
# 1       AN  No Scheduled Castes in this area              NaN       NaN
# 2   Andhra                               NaN         154470.0       NaN
# 3   Andhra                          1.Madiga         168229.0    2.Mala
# 4   Andhra                          1.Madiga         396594.0    2.Mala
# 5   Andhra                          1.Madiga         271203.0    2.Mala
# 6   Andhra                          1.Madiga         150377.0    2.Mala
# 7   Andhra                          1.Madiga         333075.0    2.Mala
# 8   Andhra                          1.Madiga         463547.0    2.Mala
# 9   Andhra                          1.Madiga         420451.0    2.Mala
# 10  Andhra                          1.Madiga         406829.0    2.Mala
# 11  Andhra                          1.Madiga         243899.0    2.Mala
# 12  Andhra                            1.Mala         156710.0  2.Madiga
# 13  Andhra                            1.Mala         126530.0  2.Madiga
# 14  Andhra                            1.Mala         169650.0  2.Madiga
# 15  Andhra                            1.Mala         416361.0  2.Madiga
# 16  Andhra                          1.Madiga         387577.0    2.Mala
# 17  Andhra                          1.Madiga         403908.0    2.Mala
# 18  Andhra                          1.Madiga         343177.0    2.Mala
# 19  Andhra                            1.Mala         373253.0  2.Madiga
#
#     SC.2.Population              SC.3.Name  SC.3.Population Religeon.1.Name  \
# 0               NaN                    NaN              NaN        1.Hindus
# 1               NaN                    NaN              NaN    1.Christians
# 2          147883.0                    NaN          73083.0             NaN
# 3          157187.0              3.Gosangi           9760.0        1.Hindus
# 4          193030.0       3.Mala Sale etc.          25595.0        1.Hindus
# 0        2.Jarawas             240                 3.Onges              96
# 1      2.Shom Pens             398  3.All Scheduled Tribes           26565
# 2   2.Sugalis etc.          103303            3.Kolam etc.           45437
# 3      2.Gond etc.           13971             3.Yerukulas            5409
# 4      2.Gond etc.           13275             3.Yerukulas           13215
# 5      2.Yerukulas           13264   3.Generic Tribes etc.            1358
# 6      2.Yerukulas            6595   3.Generic Tribes etc.            5059
# 7      2.Yerukulas           11340             3.Koya etc.            4394
# 8      2.Yerukulas           21039          3.Chenchu etc.            8272
# 9      2.Yerukulas           18531          3.Chenchu etc.             992
# 10     2.Koya etc.           61909             3.Yerukulas           19774
# 11  2.Sugalis etc.          271373             3.Gond etc.           16203
# 12       2.Jatapus           24725            3.Kotia etc.           18918
# 13  2.Konda Dhoras           51517          3.Savaras etc.           29005
# 14        2.Bagata          130301           3.Kondhs etc.           81755
# 15     2.Yerukulas           18152          3.Sugalis etc.            7223
# 16     2.Yerukulas           32445               3.Yenadis           15225
# 17     2.Yerukulas           68349               3.Yenadis           51088
# 18     2.Yerukulas           29042          3.Sugalis etc.           16290
# 19     2.Yerukulas           24289   3.Generic Tribes etc.            3253

# %%
l = l.groupby('State').sum()
l.head()
# Out:
#                   SC.1.Population  SC.2.Population  SC.3.Population  \
# State
# AN                            0.0              0.0              0.0
# Andhra                  6768865.0        3704869.0         536443.0
# ArunachalPradesh           2563.0            975.0            593.0
# Assam                    825554.0         389566.0         193433.0
# Bihar                   5682349.0        3459025.0        1740193.0
#
#                   Religeon.1.Population  Religeon.2.Population  \
# State
# AN                               264007                  59760
# Andhra                         63084642                6982178
# ArunachalPradesh                 612387                 280723
# Assam                          18771158                6933479
# Bihar                          69540029               13258938
#
#                   Religeon.3.Population
# State
# AN                                29265
# Andhra                          1055780
# ArunachalPradesh                 140535
# Assam                            819018
# Bihar                             99871

# %%
# Scatter plot

plt.figure(figsize=(13,8))
plt.scatter(x = temp['Sex.ratio..females.per.1000.males.'], y = temp['Persons..literacy.rate'],  s = np.array(temp['Persons'])/10**5, alpha = 0.8,color='g')
plt.xlabel('Sex ratio females per 1000 males')
plt.ylabel('Persons literacy rate')
plt.title('India Development')
#plt.xticks([1000,10000,100000], ['1k','10k','100k'])

plt.grid(True)
# Show the plotHousehold.size..per.household.
plt.show()

# %% [markdown]
# **Above graph shows that having better persons literacy doesn't means having better sex ratio always and it also not depends on higher population of states.**

# %%
# Scatter plot

plt.figure(figsize=(13,8))
plt.scatter(x = temp['Household.size..per.household.'], y = temp['Persons..literacy.rate'],  s = np.array(temp['Persons'])/10**5, alpha = 0.8,color='g')
plt.xlabel('Household size per household')
plt.ylabel('Persons literacy rate')
plt.title('India Development')
#plt.xticks([1000,10000,100000], ['1k','10k','100k'])

plt.grid(True)
# Show the plot
plt.show()

# %%
set(df['Religeon.2.Name'])
# Out:
# {'2.Buddhists',
#  '2.Christians',
#  '2.Hindus',
#  '2.Muslims',
#  '2.Others',
#  '2.Sikhs',
#  nan}
